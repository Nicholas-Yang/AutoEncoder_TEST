# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
import os
import pandas

# %%
data = np.random.rand(1000, 50)
data_tensor = torch.tensor(data, dtype=torch.float32)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
train_data_tensor = torch.tensor(train_data, dtype=torch.float32)
test_data_tensor = torch.tensor(test_data, dtype=torch.float32)

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(50, 20),
            nn.ReLU(),
            nn.Linear(20, 3)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(3, 20),
            nn.ReLU(),
            nn.Linear(20, 50)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
class VAE(nn.Module):
    def __init__(self, input_dim=50, hidden_dim=20, z_dim=3):
        super(VAE, self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, z_dim * 2)
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std
        
    def forward(self, x):
        h = self.encoder(x)
        mu, logvar = h.chunk(2, dim=1)
        z = self.reparameterize(mu, logvar)
        x_reconstructed = self.decoder(z)
        return x_reconstructed, mu, logvar

# %%
def vae_loss(x, x_reconstructed, mu, logvar):
    reconstruction_loss = nn.MSELoss(reduction='sum')(x_reconstructed, x)
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return reconstruction_loss + kl_divergence

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Autoencoder().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 100
batch_size = 32

for epoch in range(num_epochs):
    for i in range(0, len(train_data_tensor), batch_size):
        batch = train_data_tensor[i:i+batch_size].to(device)
        output = model(batch)
        loss = criterion(output, batch)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluation
    model.eval()
    with torch.no_grad():
        test_output = model(test_data_tensor.to(device))
        test_loss = criterion(test_output, test_data_tensor.to(device))
    model.train()

    print(f'Epoch [{epoch + 1}/{num_epochs}], Train Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}')
# Out:
# Epoch [1/100], Train Loss: 0.2140, Test Loss: 0.2062
# Epoch [2/100], Train Loss: 0.1206, Test Loss: 0.1186
# Epoch [3/100], Train Loss: 0.0895, Test Loss: 0.0882
# Epoch [4/100], Train Loss: 0.0835, Test Loss: 0.0818
# Epoch [5/100], Train Loss: 0.0825, Test Loss: 0.0811
# Epoch [6/100], Train Loss: 0.0822, Test Loss: 0.0809
# Epoch [7/100], Train Loss: 0.0820, Test Loss: 0.0808
# Epoch [8/100], Train Loss: 0.0818, Test Loss: 0.0806
# Epoch [9/100], Train Loss: 0.0815, Test Loss: 0.0805
# Epoch [10/100], Train Loss: 0.0812, Test Loss: 0.0803
# Epoch [11/100], Train Loss: 0.0809, Test Loss: 0.0801
# Epoch [12/100], Train Loss: 0.0805, Test Loss: 0.0798
# Epoch [13/100], Train Loss: 0.0802, Test Loss: 0.0796
# Epoch [14/100], Train Loss: 0.0798, Test Loss: 0.0793
# Epoch [15/100], Train Loss: 0.0793, Test Loss: 0.0790
# Epoch [16/100], Train Loss: 0.0789, Test Loss: 0.0787
# Epoch [17/100], Train Loss: 0.0785, Test Loss: 0.0785
# Epoch [18/100], Train Loss: 0.0781, Test Loss: 0.0782
# Epoch [19/100], Train Loss: 0.0778, Test Loss: 0.0780
# Epoch [20/100], Train Loss: 0.0776, Test Loss: 0.0779
# Epoch [21/100], Train Loss: 0.0774, Test Loss: 0.0777
# Epoch [22/100], Train Loss: 0.0773, Test Loss: 0.0777
# Epoch [23/100], Train Loss: 0.0772, Test Loss: 0.0776
# Epoch [24/100], Train Loss: 0.0771, Test Loss: 0.0776
# Epoch [25/100], Train Loss: 0.0770, Test Loss: 0.0776
# Epoch [26/100], Train Loss: 0.0769, Test Loss: 0.0776
# Epoch [27/100], Train Loss: 0.0769, Test Loss: 0.0776
# Epoch [28/100], Train Loss: 0.0768, Test Loss: 0.0775
# Epoch [29/100], Train Loss: 0.0768, Test Loss: 0.0775
# Epoch [30/100], Train Loss: 0.0767, Test Loss: 0.0775
# Epoch [31/100], Train Loss: 0.0767, Test Loss: 0.0775
# Epoch [32/100], Train Loss: 0.0767, Test Loss: 0.0775
# Epoch [33/100], Train Loss: 0.0766, Test Loss: 0.0775
# Epoch [34/100], Train Loss: 0.0766, Test Loss: 0.0775
# Epoch [35/100], Train Loss: 0.0766, Test Loss: 0.0775
# Epoch [36/100], Train Loss: 0.0766, Test Loss: 0.0775
# Epoch [37/100], Train Loss: 0.0766, Test Loss: 0.0775
# Epoch [38/100], Train Loss: 0.0765, Test Loss: 0.0774
# Epoch [39/100], Train Loss: 0.0765, Test Loss: 0.0774
# Epoch [40/100], Train Loss: 0.0765, Test Loss: 0.0774
# Epoch [41/100], Train Loss: 0.0765, Test Loss: 0.0774
# Epoch [42/100], Train Loss: 0.0765, Test Loss: 0.0774
# Epoch [43/100], Train Loss: 0.0764, Test Loss: 0.0774
# Epoch [44/100], Train Loss: 0.0764, Test Loss: 0.0774
# Epoch [45/100], Train Loss: 0.0764, Test Loss: 0.0774
# Epoch [46/100], Train Loss: 0.0764, Test Loss: 0.0774
# Epoch [47/100], Train Loss: 0.0764, Test Loss: 0.0774
# Epoch [48/100], Train Loss: 0.0764, Test Loss: 0.0774
# Epoch [49/100], Train Loss: 0.0764, Test Loss: 0.0774
# Epoch [50/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [51/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [52/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [53/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [54/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [55/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [56/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [57/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [58/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [59/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [60/100], Train Loss: 0.0763, Test Loss: 0.0774
# Epoch [61/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [62/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [63/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [64/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [65/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [66/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [67/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [68/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [69/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [70/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [71/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [72/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [73/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [74/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [75/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [76/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [77/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [78/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [79/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [80/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [81/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [82/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [83/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [84/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [85/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [86/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [87/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [88/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [89/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [90/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [91/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [92/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [93/100], Train Loss: 0.0764, Test Loss: 0.0773
# Epoch [94/100], Train Loss: 0.0764, Test Loss: 0.0773
# Epoch [95/100], Train Loss: 0.0764, Test Loss: 0.0773
# Epoch [96/100], Train Loss: 0.0764, Test Loss: 0.0773
# Epoch [97/100], Train Loss: 0.0764, Test Loss: 0.0773
# Epoch [98/100], Train Loss: 0.0764, Test Loss: 0.0773
# Epoch [99/100], Train Loss: 0.0763, Test Loss: 0.0773
# Epoch [100/100], Train Loss: 0.0763, Test Loss: 0.0773

# %%
#VAE Training
VAE_model = VAE().to(device)
num_epochs = 100
batch_size = 32

for epoch in range(num_epochs):
    for i in range(0, len(train_data_tensor), batch_size):
        batch = train_data_tensor[i:i+batch_size].to(device)
        x_reconstructed, mu, logvar = VAE_model(batch)
        loss = vae_loss(batch, x_reconstructed, mu, logvar)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/100], Loss:
# Epoch [64/100], Loss: 573.3312
# Epoch [65/100], Loss: 612.9545
# Epoch [66/100], Loss: 598.0153
# Epoch [67/100], Loss: 632.2037
# Epoch [68/100], Loss: 650.5259
# Epoch [69/100], Loss: 587.8517
# Epoch [70/100], Loss: 615.0589
# Epoch [71/100], Loss: 628.9926
# Epoch [72/100], Loss: 595.1515
# Epoch [73/100], Loss: 589.0075
# Epoch [74/100], Loss: 599.3092
# Epoch [75/100], Loss: 580.6683
# Epoch [76/100], Loss: 596.0339
# Epoch [77/100], Loss: 612.8357
# Epoch [78/100], Loss: 610.1133
# Epoch [79/100], Loss: 636.1851
# Epoch [80/100], Loss: 622.0460
# Epoch [81/100], Loss: 607.9553
# Epoch [82/100], Loss: 658.7852
# Epoch [83/100], Loss: 614.0553
# Epoch [84/100], Loss: 648.3835
# Epoch [85/100], Loss: 619.1277
# Epoch [86/100], Loss: 649.5884
# Epoch [87/100], Loss: 604.6027
# Epoch [88/100], Loss: 588.0214
# Epoch [89/100], Loss: 595.1666
# Epoch [90/100], Loss: 622.8781
# Epoch [91/100], Loss: 655.2959
# Epoch [92/100], Loss: 644.8870
# Epoch [93/100], Loss: 611.9947
# Epoch [94/100], Loss: 591.2637
# Epoch [95/100], Loss: 624.2525
# Epoch [96/100], Loss: 613.8964
# Epoch [97/100], Loss: 609.5226
# Epoch [98/100], Loss: 625.2797
# Epoch [99/100], Loss: 624.3525
# Epoch [100/100], Loss: 595.2665

# %%
with torch.no_grad():
    features = model.encoder(data_tensor.to(device)).cpu().numpy()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
reduced_data_pca = pca.fit_transform(data)

# %%
# Reconstruct data using PCA
reconstructed_data_pca = pca.inverse_transform(reduced_data_pca)

# Reconstruct data using AutoEncoder
with torch.no_grad():
    reconstructed_data_autoencoder = model(data_tensor.to(device)).cpu().numpy()

# mse
mse_pca = np.mean((data - reconstructed_data_pca) ** 2)
mse_autoencoder = np.mean((data - reconstructed_data_autoencoder) ** 2)

print(f'MSE for PCA: {mse_pca:.4f}')
print(f'MSE for Autoencoder: {mse_autoencoder:.4f}')
# Out:
# MSE for PCA: 0.0764
# MSE for Autoencoder: 0.0773

# %%
VAE_model.eval()
with torch.no_grad():
    test_reconstructed, _, _ = VAE_model(test_data_tensor.to(device))
    test_reconstructed = test_reconstructed.cpu().numpy()
    mse = np.mean((test_data - test_reconstructed) ** 2)

print(f'Test MSE: {mse:.4f}')
# Out:
# Test MSE: 0.3665

# %%
#Save Model
model_folder = "saved_models"
model_filename = "autoencoder.pth"

# if not exsit
if not os.path.exists(model_folder):
    os.makedirs(model_folder)

model_path = os.path.join(model_folder, model_filename)

# save model
torch.save(model.state_dict(), model_path)
